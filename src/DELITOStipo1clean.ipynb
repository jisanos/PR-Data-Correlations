# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
delitosesdf = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['EDAD Y SEXO'], header=6)


#####DATA DE PAGINA DE EDAD Y SEXO#######
edadsexo = delitosesdf.get('EDAD Y SEXO')
edadsexo = edadsexo.drop(columns=['Unnamed: 1', 'Unnamed: 5', 'Unnamed: 6'])
esdf = pd.DataFrame(edadsexo)
esdf #### < esdf >  variable de la data limpia
# Out:
#               Edades  TOTAL  Masculino  Femenino
# 0             Total     567      521.0      46.0
# 1   Menos de 10 años      1        NaN       1.0
# 2            10 a 11      0        NaN       NaN
# 3             12 a13      0        NaN       NaN
# 4            14 a 15      1        1.0       NaN
# 5            16 a 17     10        8.0       2.0
# 6            18 a 19     12       11.0       1.0
# 7            20 a 24     72       66.0       6.0
# 8            25 a 29     78       71.0       7.0
# 9            30 a 34     71       64.0       7.0
# 10           35 a 39     54       50.0       4.0
# 11           40 a 44     34       31.0       3.0
# 12           45 a 49     32       29.0       3.0
# 13           50 a 54     19       16.0       3.0
# 14           55 a 59     12        9.0       3.0
# 15           60 a 64     10        7.0       3.0
# 16          65 ó más      5        4.0       1.0
# 17      Se Desconoce    156      154.0       2.0

# %%
###data de PAGINA DE  Motivo y Sexo####
delitosMYS = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['MOTIVO Y SEXO'], header=3)
motivosexo = delitosMYS.get('MOTIVO Y SEXO')
motivosexo = motivosexo.drop(columns=['Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32'])
#mundf = municipio.drop(range(80,124)) #cortar rowa

mysdf = pd.DataFrame(motivosexo)
mysdf #### < mysdf > variable de la data limpia de motivo y sexo
# Out:
#    CLASIFICACION  Total     Total M   Total F   Peleas M  Peleas F  \
# 0          Sexo   Total   Masculino  Femenino  Masculino  Femenino
# 1         Total      567        518        49         45         4
# 2       San Juan     125        114        11         18       NaN
# 3       Arecibo       42         38         4          2         1
# 4         Ponce       34         32         2          2       NaN
# 5        Humacao      22         19         3          4       NaN
# 6      Mayagüez       35         31         4          4       NaN
# 7        Caguas       57         54         3          2       NaN
# 8       Bayamón       94         87         7          7         1
# 9       Carolina      80         75         5          5         1
# 10       Guayama      23         20         3        NaN       NaN
# 11     Aguadilla      12          9         3        NaN       NaN
# 12        Utuado       2          1         1        NaN         1
# ...

# %%
###data de PAGINA DE MUNICIPIO####
delitosMUN = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['MUNICIPIO'])
municipio = delitosMUN.get('MUNICIPIO') #seleccionar la pagina
municipio = municipio.drop(columns=['Unnamed: 10']) #cortar columnas
mundf = municipio.drop(51) #cortar rowa
mundf1 = mundf.drop(range(80,124)) #cortar rowa
mundf1 = pd.DataFrame(mundf1)
mundf1 #### < mundf1 > variable de la data municipio
# Out:
#         Distrito Tipo I Ases. Viol. Tra, Hum.  Robo Agr. Grave  Esc. Apr. I  \
# 0       Adjuntas     50     0     2         0     2         16    12     17
# 1        Aguada     116     0     2         0     4         28    13     61
# 2      Aguadilla    259     9     6         0     9         80    45    101
# 3   Aguas Buenas     81     3     1         0     6         10    11     45
# 4       Aibonito     58     2     4         0     3         18     6     14
# ..           ...    ...   ...   ...       ...   ...        ...   ...    ...
# 75       Vieques     90     2     0         0     3         33    15     29
# 76      Villalba     77     2     0         0     1         34    12     18
# 77       Yabucoa    147     8     2         0    10         55    17     49
# 78         Yauco     96     7     0         0     9         38     5     35
# 79         TOTAL  20523   567   231         1  1193       3521  2517  10034
#
#    H. Auto
# 0        1
# 1        8
# 2        9
# ...

# %%
###data de PAGINA DE Meses Puerto Rico####
delitosmes = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['MESES'], header=1)
meses = delitosmes.get('MESES') #seleccionar la pagina
mesdf= pd.DataFrame(meses)
mesdf = mesdf.drop(range(36,566)) #cortar rowa
mesdf = mesdf.drop(mesdf.loc[:,'Unnamed: 15':'Unnamed: 49'].columns, axis = 1)#cortar columnas
mesdf #### < mesdf > variable de la data MESES PR
# Out:
#                 DELITO     AÑO       ENE       FEB       MAR       ABR  \
# 0         TOTAL TIPO 1    2022      1884      1627      1702      1508
# 1         TOTAL TIPO 1    2021      1795      1428      1600      1230
# 2         TOTAL TIPO 1  CAMBIO        89       199       102       278
# 3         TOTAL TIPO 1       %  0.049582  0.139356   0.06375  0.226016
# 4   ASESINTO/HOMICIDIO    2022        55        53        41        55
# 5   ASESINTO/HOMICIDIO    2021        68        44        58        51
# 6   ASESINTO/HOMICIDIO  CAMBIO       -13         9       -17         4
# 7   ASESINTO/HOMICIDIO       % -0.191176  0.204545 -0.293103  0.078431
# 8     VIOL. POR FUERZA    2022        22        22        15        14
# 9     VIOL. POR FUERZA    2021        16        10         9        12
# 10    VIOL. POR FUERZA  CAMBIO         6        12         6         2
# 11    VIOL. POR FUERZA       %     0.375       1.2  0.666667  0.166667
# ...

# %%
###data de PAGINA DE Meses Region San Jiuan####
delitosmessj = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['MESES'], header=1)
mesessj = delitosmessj.get('MESES') #seleccionar la pagina
messjdf= pd.DataFrame(mesessj)
messjdf = messjdf.drop(range(0,40)) #cortar rowa
messjdf = messjdf.drop(range(76,566)) #cortar rowa
messjdf = messjdf.drop(messjdf.loc[:,'Unnamed: 15':'Unnamed: 49'].columns, axis = 1)#cortar columnas
messjdf #### < messjdf > variable de la data MESES region san juan
# Out:
#                 DELITO     AÑO       ENE       FEB       MAR       ABR  \
# 40        TOTAL TIPO 1    2022       443       405       391       347
# 41        TOTAL TIPO 1    2021       353       283       315       258
# 42        TOTAL TIPO 1  CAMBIO        90       122        76        89
# 43        TOTAL TIPO 1       %  0.254958  0.431095   0.24127  0.344961
# 44  ASESINTO/HOMICIDIO    2022        13        10         3        10
# 45  ASESINTO/HOMICIDIO    2021        11         9        14        13
# 46  ASESINTO/HOMICIDIO  CAMBIO         2         1       -11        -3
# 47  ASESINTO/HOMICIDIO       %  0.181818  0.111111 -0.785714 -0.230769
# 48    VIOL. POR FUERZA    2022         6         5         3         3
# 49    VIOL. POR FUERZA    2021         6         1         1         2
# 50    VIOL. POR FUERZA  CAMBIO         0         4         2         1
# 51    VIOL. POR FUERZA       %         0         4         2       0.5
# ...

# %%
###data de PAGINA DE Meses Region ARECIBO####
delitosmesare = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['MESES'], header=1)
mesesare = delitosmesare.get('MESES') #seleccionar la pagina
mesaredf= pd.DataFrame(mesesare)
mesaredf = mesaredf.drop(range(0,80)) #cortar rowa
mesaredf = mesaredf.drop(range(116,566)) #cortar rowa
mesaredf = mesaredf.drop(mesaredf.loc[:,'Unnamed: 15':'Unnamed: 49'].columns, axis = 1)#cortar columnas
mesaredf #### < mesaredf > variable de la data MESES region Arecibo
# Out:
#                  DELITO     AÑO       ENE       FEB       MAR       ABR  \
# 80         TOTAL TIPO 1    2022       154       119       117        99
# 81         TOTAL TIPO 1    2021       183       137       140       127
# 82         TOTAL TIPO 1  CAMBIO       -29       -18       -23       -28
# 83         TOTAL TIPO 1       %  -0.15847 -0.131387 -0.164286 -0.220472
# 84   ASESINTO/HOMICIDIO    2022         2         9         4         3
# 85   ASESINTO/HOMICIDIO    2021         3         4         4         8
# 86   ASESINTO/HOMICIDIO  CAMBIO        -1         5         0        -5
# 87   ASESINTO/HOMICIDIO       % -0.333333      1.25         0    -0.625
# 88     VIOL. POR FUERZA    2022         2         3         3         1
# 89     VIOL. POR FUERZA    2021         2         0         1         1
# 90     VIOL. POR FUERZA  CAMBIO         0         3         2         0
# 91     VIOL. POR FUERZA       %         0         0         2         0
# ...

# %%
###data de PAGINA DE Meses Region PONCE####
delitosmespon = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['MESES'], header=1)
mesespon = delitosmespon.get('MESES') #seleccionar la pagina
mespondf= pd.DataFrame(mesesare)
mespondf = mespondf.drop(range(0,120)) #cortar rowa
mespondf = mespondf.drop(range(156,566)) #cortar rowa
mespondf = mespondf.drop(mespondf.loc[:,'Unnamed: 15':'Unnamed: 49'].columns, axis = 1)#cortar columnas
mespondf #### < mespondf > variable de la data MESES region ponce
# Out:
#                  DELITO     AÑO       ENE       FEB       MAR       ABR  \
# 120        TOTAL TIPO 1    2022       127        98        98        81
# 121        TOTAL TIPO 1    2021       108        86       104        77
# 122        TOTAL TIPO 1  CAMBIO        19        12        -6         4
# 123        TOTAL TIPO 1       %  0.175926  0.139535 -0.057692  0.051948
# 124  ASESINTO/HOMICIDIO    2022         3         2         3         4
# 125  ASESINTO/HOMICIDIO    2021         2         5         6         5
# 126  ASESINTO/HOMICIDIO  CAMBIO         1        -3        -3        -1
# 127  ASESINTO/HOMICIDIO       %       0.5      -0.6      -0.5      -0.2
# 128    VIOL. POR FUERZA    2022         0         1         0         1
# 129    VIOL. POR FUERZA    2021         1         0         1         1
# 130    VIOL. POR FUERZA  CAMBIO        -1         1        -1         0
# 131    VIOL. POR FUERZA       %        -1         0        -1         0
# ...

# %%
###data de PAGINA DE Meses Region HUMACAO####
delitosmeshum = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['MESES'], header=1)
meseshum = delitosmeshum.get('MESES') #seleccionar la pagina
meshumdf= pd.DataFrame(meseshum)
meshumdf = meshumdf.drop(range(0,160)) #cortar rowa
meshumdf = meshumdf.drop(range(196,566)) #cortar rowa
meshumdf = meshumdf.drop(meshumdf.loc[:,'Unnamed: 15':'Unnamed: 49'].columns, axis = 1)#cortar columnas
meshumdf #### < meshumdf > variable de la data MESES region humacao
# Out:
#                  DELITO     AÑO       ENE       FEB       MAR       ABR  \
# 160        TOTAL TIPO 1    2022        70        49        76        44
# 161        TOTAL TIPO 1    2021        79        53        63        44
# 162        TOTAL TIPO 1  CAMBIO        -9        -4        13         0
# 163        TOTAL TIPO 1       % -0.113924 -0.075472  0.206349         0
# 164  ASESINTO/HOMICIDIO    2022         1         2         4         2
# 165  ASESINTO/HOMICIDIO    2021         2         3         4         3
# 166  ASESINTO/HOMICIDIO  CAMBIO        -1        -1         0        -1
# 167  ASESINTO/HOMICIDIO       %      -0.5 -0.333333         0 -0.333333
# 168    VIOL. POR FUERZA    2022         0         2         1         1
# 169    VIOL. POR FUERZA    2021         0         0         0         1
# 170    VIOL. POR FUERZA  CAMBIO         0         2         1         0
# 171    VIOL. POR FUERZA       %         0         0         0         0
# ...

# %%
###data de PAGINA DE Meses Region MAYAGUEZ####
delitosmesmay = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['MESES'], header=1)
mesesmay = delitosmesmay.get('MESES') #seleccionar la pagina
mesmaydf= pd.DataFrame(mesesmay)
mesmaydf = mesmaydf.drop(range(0,200)) #cortar rowa
mesmaydf = mesmaydf.drop(range(236,566)) #cortar rowa
mesmaydf = mesmaydf.drop(mesmaydf.loc[:,'Unnamed: 15':'Unnamed: 49'].columns, axis = 1)#cortar columnas
mesmaydf #### < mesmaydf > variable de la data MESES region mayo
# Out:
#                  DELITO     AÑO       ENE       FEB       MAR       ABR  \
# 200        TOTAL TIPO 1    2022        68        49        76        61
# 201        TOTAL TIPO 1    2021        62        43        43        35
# 202        TOTAL TIPO 1  CAMBIO         6         6        33        26
# 203        TOTAL TIPO 1       %  0.096774  0.139535  0.767442  0.742857
# 204  ASESINTO/HOMICIDIO    2022         6         3         3         4
# 205  ASESINTO/HOMICIDIO    2021         7         3         1         1
# 206  ASESINTO/HOMICIDIO  CAMBIO        -1         0         2         3
# 207  ASESINTO/HOMICIDIO       % -0.142857         0         2         3
# 208    VIOL. POR FUERZA    2022         0         0         0         0
# 209    VIOL. POR FUERZA    2021         2         2         0         1
# 210    VIOL. POR FUERZA  CAMBIO        -2        -2         0        -1
# 211    VIOL. POR FUERZA       %        -1        -1         0        -1
# ...

# %%
###data de PAGINA DE Meses Region CAGUAS####
delitosmescag = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['MESES'], header=1)
mesescag = delitosmescag.get('MESES') #seleccionar la pagina
mescagdf= pd.DataFrame(mesescag)
mescagdf = mescagdf.drop(range(0,240)) #cortar rowa
mescagdf = mescagdf.drop(range(276,566)) #cortar rowa
mescagdf = mescagdf.drop(mescagdf.loc[:,'Unnamed: 15':'Unnamed: 49'].columns, axis = 1)#cortar columnas
mescagdf #### < mescagdf > variable de la data MESES region caguas
# Out:
#                  DELITO     AÑO       ENE       FEB       MAR       ABR  \
# 240        TOTAL TIPO 1    2022       138       142       169       159
# 241        TOTAL TIPO 1    2021       133       131       146       118
# 242        TOTAL TIPO 1  CAMBIO         5        11        23        41
# 243        TOTAL TIPO 1       %  0.037594  0.083969  0.157534  0.347458
# 244  ASESINTO/HOMICIDIO    2022         7         5         2         4
# 245  ASESINTO/HOMICIDIO    2021        12         3         4         4
# 246  ASESINTO/HOMICIDIO  CAMBIO        -5         2        -2         0
# 247  ASESINTO/HOMICIDIO       % -0.416667  0.666667      -0.5         0
# 248    VIOL. POR FUERZA    2022         3         1         1         1
# 249    VIOL. POR FUERZA    2021         0         0         1         1
# 250    VIOL. POR FUERZA  CAMBIO         3         1         0         0
# 251    VIOL. POR FUERZA       %         0         0         0         0
# ...

# %%
###data de PAGINA DE Meses Region BAYAMON####
delitosmesbay = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['MESES'], header=1)
mesesbay = delitosmesbay.get('MESES') #seleccionar la pagina
mesbaydf= pd.DataFrame(mesesbay)
mesbaydf = mesbaydf.drop(range(0,280)) #cortar rowa
mesbaydf = mesbaydf.drop(range(316,566)) #cortar rowa
mesbaydf = mesbaydf.drop(mesbaydf.loc[:,'Unnamed: 15':'Unnamed: 49'].columns, axis = 1)#cortar columnas
mesbaydf #### < mesbaydf > variable de la data MESES region bayamon
# Out:
#                  DELITO     AÑO       ENE       FEB       MAR       ABR  \
# 280        TOTAL TIPO 1    2022       454       371       359       352
# 281        TOTAL TIPO 1    2021       401       347       378       310
# 282        TOTAL TIPO 1  CAMBIO        53        24       -19        42
# 283        TOTAL TIPO 1       %   0.13217  0.069164 -0.050265  0.135484
# 284  ASESINTO/HOMICIDIO    2022         9         8         5        10
# 285  ASESINTO/HOMICIDIO    2021        10         9         6        10
# 286  ASESINTO/HOMICIDIO  CAMBIO        -1        -1        -1         0
# 287  ASESINTO/HOMICIDIO       %      -0.1 -0.111111 -0.166667         0
# 288    VIOL. POR FUERZA    2022         1         2         2         1
# 289    VIOL. POR FUERZA    2021         3         1         2         1
# 290    VIOL. POR FUERZA  CAMBIO        -2         1         0         0
# 291    VIOL. POR FUERZA       % -0.666667         1         0         0
# ...

# %%
###data de PAGINA DE Meses Region CAROLINA####
delitosmescar = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['MESES'], header=1)
mesescar = delitosmescar.get('MESES') #seleccionar la pagina
mescardf= pd.DataFrame(mesescar)
mescardf = mescardf.drop(range(0,320)) #cortar rowa
mescardf = mescardf.drop(range(356,566)) #cortar rowa
mescardf = mescardf.drop(mescardf.loc[:,'Unnamed: 15':'Unnamed: 49'].columns, axis = 1)#cortar columnas
mescardf #### < mescardf > variable de la data MESES region car
# Out:
#                  DELITO     AÑO       ENE       FEB       MAR       ABR  \
# 320        TOTAL TIPO 1    2022       185       212       191       180
# 321        TOTAL TIPO 1    2021       191       152       162       118
# 322        TOTAL TIPO 1  CAMBIO        -6        60        29        62
# 323        TOTAL TIPO 1       % -0.031414  0.394737  0.179012  0.525424
# 324  ASESINTO/HOMICIDIO    2022         6         6        10        11
# 325  ASESINTO/HOMICIDIO    2021        11         1        13         4
# 326  ASESINTO/HOMICIDIO  CAMBIO        -5         5        -3         7
# 327  ASESINTO/HOMICIDIO       % -0.454545         5 -0.230769      1.75
# 328    VIOL. POR FUERZA    2022         2         3         5         2
# 329    VIOL. POR FUERZA    2021         1         1         3         3
# 330    VIOL. POR FUERZA  CAMBIO         1         2         2        -1
# 331    VIOL. POR FUERZA       %         1         2  0.666667 -0.333333
# ...

# %%
###data de PAGINA DE Meses Region GUAYAMA####
delitosmesgua = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['MESES'], header=1)
mesesgua = delitosmesgua.get('MESES') #seleccionar la pagina
mesguadf= pd.DataFrame(mesesgua)
mesguadf = mesguadf.drop(range(0,360)) #cortar rowa
mesguadf = mesguadf.drop(range(396,566)) #cortar rowa
mesguadf = mesguadf.drop(mesguadf.loc[:,'Unnamed: 15':'Unnamed: 49'].columns, axis = 1)#cortar columnas
mesguadf #### < mesguadf > variable de la data MESES region guayama
# Out:
#                  DELITO     AÑO       ENE       FEB       MAR       ABR  \
# 360        TOTAL TIPO 1    2022        41        31        40        37
# 361        TOTAL TIPO 1    2021        48        23        44        28
# 362        TOTAL TIPO 1  CAMBIO        -7         8        -4         9
# 363        TOTAL TIPO 1       % -0.145833  0.347826 -0.090909  0.321429
# 364  ASESINTO/HOMICIDIO    2022         5         4         2         2
# 365  ASESINTO/HOMICIDIO    2021         3         0         2         1
# 366  ASESINTO/HOMICIDIO  CAMBIO         2         4         0         1
# 367  ASESINTO/HOMICIDIO       %  0.666667         0         0         1
# 368    VIOL. POR FUERZA    2022         0         1         0         1
# 369    VIOL. POR FUERZA    2021         0         0         0         0
# 370    VIOL. POR FUERZA  CAMBIO         0         1         0         1
# 371    VIOL. POR FUERZA       %         0         0         0         0
# ...

# %%
###data de PAGINA DE Meses Region AGUADILLA####
delitosmesagu = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['MESES'], header=1)
mesesagu = delitosmesagu.get('MESES') #seleccionar la pagina
mesagudf= pd.DataFrame(mesesagu)
mesagudf = mesagudf.drop(range(0,400)) #cortar rowa
mesagudf = mesagudf.drop(range(436,566)) #cortar rowa
mesagudf = mesagudf.drop(mesagudf.loc[:,'Unnamed: 15':'Unnamed: 49'].columns, axis = 1)#cortar columnas
mesagudf #### < mesagudf > variable de la data MESES region aguadilla
# Out:
#                  DELITO     AÑO       ENE       FEB       MAR       ABR  \
# 400        TOTAL TIPO 1    2022        81        40        63        45
# 401        TOTAL TIPO 1    2021        76        65        89        34
# 402        TOTAL TIPO 1  CAMBIO         5       -25       -26        11
# 403        TOTAL TIPO 1       %  0.065789 -0.384615 -0.292135  0.323529
# 404  ASESINTO/HOMICIDIO    2022         1         1         0         1
# 405  ASESINTO/HOMICIDIO    2021         2         3         2         0
# 406  ASESINTO/HOMICIDIO  CAMBIO        -1        -2        -2         1
# 407  ASESINTO/HOMICIDIO       %      -0.5 -0.666667        -1         0
# 408    VIOL. POR FUERZA    2022         4         1         0         0
# 409    VIOL. POR FUERZA    2021         1         4         0         0
# 410    VIOL. POR FUERZA  CAMBIO         3        -3         0         0
# 411    VIOL. POR FUERZA       %         3     -0.75         0         0
# ...

# %%
###data de PAGINA DE Meses Region UTUADO####
delitosmesutu = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['MESES'], header=1)
mesesutu = delitosmesutu.get('MESES') #seleccionar la pagina
mesutudf= pd.DataFrame(mesesutu)
mesutudf = mesutudf.drop(range(0,440)) #cortar rowa
mesutudf = mesutudf.drop(range(476,566)) #cortar rowa
mesutudf = mesutudf.drop(mesutudf.loc[:,'Unnamed: 15':'Unnamed: 49'].columns, axis = 1)#cortar columnas
mesutudf #### < mesutudf > variable de la data MESES region UTUADO
# Out:
#                  DELITO     AÑO       ENE       FEB    MAR       ABR  \
# 440        TOTAL TIPO 1    2022        25        27     21        28
# 441        TOTAL TIPO 1    2021        22        19     24        17
# 442        TOTAL TIPO 1  CAMBIO         3         8     -3        11
# 443        TOTAL TIPO 1       %  0.136364  0.421053 -0.125  0.647059
# 444  ASESINTO/HOMICIDIO    2022         0         0      0         0
# 445  ASESINTO/HOMICIDIO    2021         1         0      0         0
# 446  ASESINTO/HOMICIDIO  CAMBIO        -1         0      0         0
# 447  ASESINTO/HOMICIDIO       %        -1         0      0         0
# 448    VIOL. POR FUERZA    2022         0         0      0         2
# 449    VIOL. POR FUERZA    2021         0         0      0         0
# 450    VIOL. POR FUERZA  CAMBIO         0         0      0         2
# 451    VIOL. POR FUERZA       %         0         0      0         0
# 452        TRATA HUMANA    2022         0         0      0         0
# ...

# %%
###data de PAGINA DE Meses Region FAJARDO####
delitosmesfaj = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['MESES'], header=1)
mesesfaj = delitosmesfaj.get('MESES') #seleccionar la pagina
mesfajdf= pd.DataFrame(mesesfaj)
mesfajdf = mesfajdf.drop(range(0,480)) #cortar rowa
mesfajdf = mesfajdf.drop(range(516,566)) #cortar rowa
mesfajdf = mesfajdf.drop(mesfajdf.loc[:,'Unnamed: 15':'Unnamed: 49'].columns, axis = 1)#cortar columnas
mesfajdf #### < mesfajdf > variable de la data MESES region FAJARDO
# Out:
#                  DELITO     AÑO       ENE       FEB       MAR       ABR  \
# 480        TOTAL TIPO 1    2022        66        52        59        51
# 481        TOTAL TIPO 1    2021        80        61        65        47
# 482        TOTAL TIPO 1  CAMBIO       -14        -9        -6         4
# 483        TOTAL TIPO 1       %    -0.175 -0.147541 -0.092308  0.085106
# 484  ASESINTO/HOMICIDIO    2022         0         3         2         2
# 485  ASESINTO/HOMICIDIO    2021         2         4         2         2
# 486  ASESINTO/HOMICIDIO  CAMBIO        -2        -1         0         0
# 487  ASESINTO/HOMICIDIO       %        -1     -0.25         0         0
# 488    VIOL. POR FUERZA    2022         0         1         0         0
# 489    VIOL. POR FUERZA    2021         0         1         0         1
# 490    VIOL. POR FUERZA  CAMBIO         0         0         0        -1
# 491    VIOL. POR FUERZA       %         0         0         0        -1
# ...

# %%
###data de PAGINA DE Meses Region AIBONITO####
delitosmesaib = pd.read_excel(r"C:\Users\Adam\Downloads\Policia-DelitosTipoI-2022-12.xls",
                       sheet_name=['MESES'], header=1)
mesesaib = delitosmesaib.get('MESES') #seleccionar la pagina
mesaibdf= pd.DataFrame(mesesaib)
mesaibdf = mesaibdf.drop(range(0,520)) #cortar rowa
mesaibdf = mesaibdf.drop(range(556,566)) #cortar rowa
mesaibdf = mesaibdf.drop(mesaibdf.loc[:,'Unnamed: 15':'Unnamed: 49'].columns, axis = 1)#cortar columnas
mesaibdf #### < mesaibdf > variable de la data MESES region aibonito
# Out:
#                  DELITO     AÑO       ENE       FEB       MAR       ABR  \
# 520        TOTAL TIPO 1    2022        32        32        42        24
# 521        TOTAL TIPO 1    2021        59        28        27        17
# 522        TOTAL TIPO 1  CAMBIO       -27         4        15         7
# 523        TOTAL TIPO 1       % -0.457627  0.142857  0.555556  0.411765
# 524  ASESINTO/HOMICIDIO    2022         2         0         3         2
# 525  ASESINTO/HOMICIDIO    2021         2         0         0         0
# 526  ASESINTO/HOMICIDIO  CAMBIO         0         0         3         2
# 527  ASESINTO/HOMICIDIO       %         0         0         0         0
# 528    VIOL. POR FUERZA    2022         4         2         0         1
# 529    VIOL. POR FUERZA    2021         0         0         0         0
# 530    VIOL. POR FUERZA  CAMBIO         4         2         0         1
# 531    VIOL. POR FUERZA       %         0         0         0         0
# ...
