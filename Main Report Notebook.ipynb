# %% [markdown]
# ## Members
#
# | Name             | e-mail                   | GitHub Username  |
# |------------------|--------------------------|------------------|
# | Hector Sanchez   | hector.sanchez42@upr.edu | Jisanos          |
# | Juan Hernandez   | juan.hernandez41@upr.edu | JuanHdez1        |
# | Adam Nunez       | adam.nunez@upr.edu       | grumpyandres     |
# | Jasiel Rivera    | jasiel.rivera@upr.edu    | jasielrt95       |
# | Angel Romero     | angel.romero5@upr.edu    | AngelRomero5     |
# | Sergio Mattei    | sergio.mattei@upr.edu    | matteing         |
# | Hallyma Gauthier | hallyma.gauthier@upr.edu | hallyma-gauthier |

# %% [markdown]
# # Is ther a relation between unemployment rates and violent crimes in the municipalities of Puerto Rico?

# %% [markdown]
# Before the group came up with this question, we performed some data gathering and cleanup tasks to determine what data existed and if they contained enough metrics for us to come up with something worth while.
#
# The data found ranged from the following:
#
# - [Employment and Unemployments in each municipality of PR](https://indicadores.pr/id/dataset/estadisticas-de-desempleo-de-area-local/resource/3782a13d-96dd-4cab-adb2-5ace776c6f8a)
# - [Bankrupcy Filings in PR](https://estadisticas.pr/files/inventario/quiebras/2023-04-17/USBC-BankruptcyFilings-2023-03.pdf)
# - [Criminality (Type 1 Offences) in each municipality of PR](https://estadisticas.pr/en/inventario-de-estadisticas/delitos_tipo_i)
# - [Electricity Outages in PR by LUMA](https://luma-outages.jpadilla.com/data?sql=select+*+from+customers)
# - [Generation, consumption, cost, increesos and customers of the PR electrical system (LUMA)](https://www.indicadores.pr/dataset/generacion-consumo-costo-ingresos-y-clientes-del-sistema-electrico-de-puerto-rico/resource/8025f821-45c1-4c6a-b2f4-8d641cc03df1)
# - [Population Change in PR](https://censo.estadisticas.pr/EstimadosPoblacionales)
# - [Earthquake Activity in PR](https://redsismica.uprm.edu/spanish/sismicidad/catalogos/catalogo_general.php)
# - [Registered Deaths in PR](https://datos.estadisticas.pr/dataset/defunciones-registradas)
#
# Each member was assigned to clean one of these datasets so that we could at the end determine possible ideas for the project. These ideas ended up ranging from:
#
# - Correlation between unemployment and bankrupcy
# - Correlation between unemployment and type 1 offences
# - Correlation between mortality rate and type 1 offeneces
# - Correlation between electricity outages and earthquakes
# - Correlation between economic factors, natural disasters, mortality rate, electricity outages, and increase or reduction of population
# - Correlation between bankrupcy and COVID-19 cases.
#
# Given what most thought was most important, and what data was actually available for us to tackle, we decided to go with the current topic.

# %% [markdown]
# ## Cleaning the Data

# %% [markdown]
# ### Type 1 Offences

# %%
import pandas as pd
from glob import glob
import os

# %%
# Finding all xls files in the directory of delitos
files = glob("./data/raw/Delitos Tipo 1/*/*.xls")
files.extend(glob("./data/raw/Delitos Tipo 1/*/*.xlsx"))

# %%
# When importing each xls, a new column will be created to identify the year-month by its file name
df = pd.DataFrame()
for f in files:
    
    tmp = pd.read_excel(f, sheet_name="MUNICIPIOS")
    # Dropping rows with all nans before assigning year_month value
    tmp.dropna(how='all', inplace=True)
    # Dropping columns with all nans as well
    tmp.dropna(axis=1, how='all', inplace=True)
    
    # In the case that the columns have inconsistent names,
    # they will be renamed appropriately.
    tmp.rename({"Trata Humana":"Trata Hum.",
                "Agresión Grave":"Agr. Grave",
                "Violación":"Viol.",
                "Apropiación Ilegal":"Apr. I",
                "Escalamiento":"Esc.",
                "Hurto Auto":"H. Auto",
                "Asesinato":"Ases.",
                }, axis=1, inplace=True)
    
    year_month = os.path.basename(f).removeprefix("Policia_DelitosTipoI_").removesuffix(".xls").removesuffix(".xlsx")
    year_month = year_month[:4] + '-' + year_month[4:]
    tmp['Date'] = year_month
    
    df = pd.concat([df, tmp])

# %%
df.reset_index(inplace=True, drop=True)

# %%
# Will drop TOTAL rows from district
df = df[~(df['Distrito'] == 'TOTAL')]

# %%
# Will drop randomly inserted row that repeats the header
df = df[~(df['Distrito'] == 'Distrito')]

# %%
df.reset_index(inplace=True, drop=True)

# %%
df.columns
# Some column names have been shortened so they must be merged
# since they represent the same values. This rename will be done
# before concattenating the dataframes.
# Out:
# Index(['Distrito', 'Tipo I', 'Ases.', 'Viol.', 'Robo', 'Agr. Grave', 'Esc.',
#        'Apr. I', 'H. Auto', 'Date', 'Trata Hum.', 'Unnamed: 10', 'Unnamed: 9',
#        'Unnamed: 20', 'AREA'],
#       dtype='object')

# %%
assoc_columns = {"Trata Humana":"Trata Hum.",
                "Agresión Grave":"Agr. Grave",
                "Violación":"Viol.",
                "Apropiación Ilegal":"Apr. I",
                "Escalamiento":"Esc.",
                "Hurto Auto":"H. Auto",
                "Asesinato":"Ases.",
                }

# %%
df.isna().sum()
# Out:
# Distrito          21
# Tipo I            21
# Ases.            181
# Viol.            333
# Robo              77
# Agr. Grave        26
# Esc.              28
# Apr. I            21
# H. Auto          107
# Date               0
# Trata Hum.      5201
# Unnamed: 10    10315
# Unnamed: 9     10298
# Unnamed: 20    10304
# AREA           10239
# dtype: int64

# %%
# Trata humana has too many missing values to be significant
df.drop('Trata Hum.', axis=1, inplace=True)

# %%
df
# Out:
#            Distrito Tipo I Ases. Viol. Robo Agr. Grave Esc. Apr. I H. Auto  \
# 0          Adjuntas    117     0     0    6          5   32     69       5
# 1           Aguada     323     4     2   19         13   78    194      13
# 2         Aguadilla    736     5     2   30         24  280    374      21
# 3      Aguas Buenas    261     6     0   28         14  102     89      22
# 4          Aibonito    232     8     0   14         15   62    104      29
# ...             ...    ...   ...   ...  ...        ...  ...    ...     ...
# 10312     Vega Baja    155     5     1    9         14   38     74      14
# 10313       Vieques     47     3     0    0         11   16     15       2
# 10314      Villalba     14     0     0    1          5    3      5       0
# 10315       Yabucoa     32     0     2    0          8    9     12       1
# 10316         Yauco     38     1     0    3         14   11      8       1
#
#           Date Unnamed: 10 Unnamed: 9  Unnamed: 20 AREA
# 0      2014-12         NaN        NaN          NaN  NaN
# 1      2014-12         NaN        NaN          NaN  NaN
# 2      2014-12         NaN        NaN          NaN  NaN
# 3      2014-12         NaN        NaN          NaN  NaN
# 4      2014-12         NaN        NaN          NaN  NaN
# ...        ...         ...        ...          ...  ...
# 10312  2020-04         NaN        NaN          NaN  NaN
# 10313  2020-04         NaN        NaN          NaN  NaN
# 10314  2020-04         NaN        NaN          NaN  NaN
# 10315  2020-04         NaN        NaN          NaN  NaN
# 10316  2020-04         NaN        NaN          NaN  NaN
#
# [10317 rows x 14 columns]

# %%
# sorted(list(df['Date'].unique()))

# %%
df[~df['Distrito'].isna()]
# Out:
#            Distrito Tipo I Ases. Viol. Robo Agr. Grave Esc. Apr. I H. Auto  \
# 0          Adjuntas    117     0     0    6          5   32     69       5
# 1           Aguada     323     4     2   19         13   78    194      13
# 2         Aguadilla    736     5     2   30         24  280    374      21
# 3      Aguas Buenas    261     6     0   28         14  102     89      22
# 4          Aibonito    232     8     0   14         15   62    104      29
# ...             ...    ...   ...   ...  ...        ...  ...    ...     ...
# 10312     Vega Baja    155     5     1    9         14   38     74      14
# 10313       Vieques     47     3     0    0         11   16     15       2
# 10314      Villalba     14     0     0    1          5    3      5       0
# 10315       Yabucoa     32     0     2    0          8    9     12       1
# 10316         Yauco     38     1     0    3         14   11      8       1
#
#           Date Unnamed: 10 Unnamed: 9  Unnamed: 20 AREA
# 0      2014-12         NaN        NaN          NaN  NaN
# 1      2014-12         NaN        NaN          NaN  NaN
# 2      2014-12         NaN        NaN          NaN  NaN
# 3      2014-12         NaN        NaN          NaN  NaN
# 4      2014-12         NaN        NaN          NaN  NaN
# ...        ...         ...        ...          ...  ...
# 10312  2020-04         NaN        NaN          NaN  NaN
# 10313  2020-04         NaN        NaN          NaN  NaN
# 10314  2020-04         NaN        NaN          NaN  NaN
# 10315  2020-04         NaN        NaN          NaN  NaN
# 10316  2020-04         NaN        NaN          NaN  NaN
#
# [10296 rows x 14 columns]

# %%
df[~(df['AREA'].isna())]
# Area was oddly added in the Policia_DelitosTipoI_201612 spreadsheet
# Out:
#           Distrito Tipo I Ases. Viol.  Robo Agr. Grave Esc. Apr. I H. Auto  \
# 5636      Adjuntas     78   0.0   0.0   2.0         18   30     28     0.0
# 5637       Aguada     256   2.0   1.0  14.0         41   78    112     8.0
# 5638     Aguadilla    598   9.0   2.0  27.0         92  174    281    13.0
# 5639  Aguas Buenas    201   8.0   1.0  24.0         14   44     81    29.0
# 5640      Aibonito    206   6.0   0.0  13.0         16   52    105    14.0
# ...            ...    ...   ...   ...   ...        ...  ...    ...     ...
# 5709     Vega Baja    936   6.0   3.0  76.0         35  262    467    87.0
# 5710       Vieques    161   2.0   2.0   1.0         27   51     77     1.0
# 5711      Villalba    138   1.0   1.0   1.0         28   35     67     5.0
# 5712       Yabucoa    212   5.0   1.0  13.0         26   66     97     4.0
# 5713         Yauco    255   7.0   3.0   7.0         71   36    128     3.0
#
#          Date Unnamed: 10 Unnamed: 9  Unnamed: 20       AREA
# 5636  2016-12         NaN        NaN          NaN     UTUADO
# 5637  2016-12         NaN        NaN          NaN  AGUADILLA
# 5638  2016-12         NaN        NaN          NaN  AGUADILLA
# 5639  2016-12         NaN        NaN          NaN     CAGUAS
# 5640  2016-12         NaN        NaN          NaN   AIBONITO
# ...       ...         ...        ...          ...        ...
# 5709  2016-12         NaN        NaN          NaN    BAYAMON
# 5710  2016-12         NaN        NaN          NaN    FAJARDO
# 5711  2016-12         NaN        NaN          NaN      PONCE
# 5712  2016-12         NaN        NaN          NaN    HUMACAO
# 5713  2016-12         NaN        NaN          NaN      PONCE
#
# [78 rows x 14 columns]

# %%
df.drop('AREA',axis=1,inplace=True)

# %%
# df[~(df['Unnamed: 5'].isna())]
# There are some weird cases where the header did
# not extract properly and the column positions shifted.
# This seems to happen when the first row in the MUNICIPIOS
# sheet is empty, so the header is not extracted properly.
# Straightforward fix is to remove the empty row from the
# spreadsheet directly and manually.

# %%
df[~(df['Unnamed: 10'].isna())]
# Unnamed: 10 seems to contain the data of Tipo 1 of some
# of the spreadsheets I converted from pdf to xls online.
# This happens because some of the columns are merged in the
# spreadsheet so the easiest solution is to fix it directly on
# the sheets by merging those cases.
# Once fixing that, it can be dropped
# Out:
#      Distrito Tipo I Ases. Viol. Robo Agr. Grave Esc. Apr. I H. Auto     Date  \
# 1716      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2015-11
# 6416      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2016-03
#
#      Unnamed: 10 Unnamed: 9  Unnamed: 20
# 1716                    NaN          NaN
# 6416                    NaN          NaN

# %%
df[~(df['Unnamed: 9'].isna())]
# Nothing significant here. Can be dropped.
# Out:
#      Distrito Tipo I Ases. Viol. Robo Agr. Grave Esc. Apr. I H. Auto     Date  \
# 2185      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2013-12
# 3200      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2012-06
# 3825      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2011-01
# 3904      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2011-02
# 3983      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2011-03
# 4062      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2011-04
# 4141      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2011-05
# 4766      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2010-01
# 4845      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2010-09
# 4924      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2010-02
# 5003      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2010-03
# 5082      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2010-08
# 5161      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2010-04
# 5240      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2010-05
# 5319      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2010-06
# 5398      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2010-07
# 5477      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2010-10
# 5556      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2010-11
# 5635      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2010-12
#
#      Unnamed: 10 Unnamed: 9  Unnamed: 20
# 2185         NaN                     NaN
# 3200         NaN                     NaN
# 3825         NaN                     NaN
# 3904         NaN                     NaN
# 3983         NaN                     NaN
# 4062         NaN                     NaN
# 4141         NaN                     NaN
# 4766         NaN                     NaN
# 4845         NaN                     NaN
# 4924         NaN                     NaN
# 5003         NaN                     NaN
# 5082         NaN                     NaN
# 5161         NaN                     NaN
# 5240         NaN                     NaN
# 5319         NaN                     NaN
# 5398         NaN                     NaN
# 5477         NaN                     NaN
# 5556         NaN                     NaN
# 5635         NaN                     NaN

# %%
df.drop('Unnamed: 9', axis=1, inplace=True)

# %%
df[~(df['Unnamed: 10'].isna())]
# Out:
#      Distrito Tipo I Ases. Viol. Robo Agr. Grave Esc. Apr. I H. Auto     Date  \
# 1716      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2015-11
# 6416      NaN    NaN   NaN   NaN  NaN        NaN  NaN    NaN     NaN  2016-03
#
#      Unnamed: 10  Unnamed: 20
# 1716                      NaN
# 6416                      NaN

# %%
df.drop('Unnamed: 10', axis=1, inplace=True)

# %%
df[~(df['Unnamed: 20'].isna())]
# Sometimes a 3 slips here, this column can be dropped
# Out:
#      Distrito Tipo I Ases. Viol. Robo Agr. Grave Esc. Apr. I H. Auto     Date  \
# 2134  Florida    160     4     0    7          7   69     68       5  2013-12
# 3149  Florida     60     0     0    4          0   33     19       4  2012-06
# 3853  Florida     34     7     0    2          0   17      6       2  2011-02
# 3932  Florida     37     7     0    2          0   19      7       2  2011-03
# 4011  Florida     42     7     0    2          0   23      8       2  2011-04
# 4090  Florida     55     7     0    2          1   34      8       3  2011-05
# 4873  Florida     24     0     0    0          0   15      6       3  2010-02
# 4952  Florida     32     0     0    1          0   21      7       3  2010-03
# 5110  Florida     47     1     0    4          0   25     11       6  2010-04
# 5189  Florida     61     1     0    4          0   34     14       8  2010-05
# 5268  Florida     70     2     0    4          3   37     18       6  2010-06
# 5347  Florida    107     2     0    5          3   48     34      15  2010-07
# 5584  Florida    162     2     0    9          6   80     57       8  2010-12
#
#       Unnamed: 20
# 2134          3.0
# 3149          3.0
# 3853          3.0
# 3932          3.0
# 4011          3.0
# 4090          3.0
# 4873          3.0
# 4952          3.0
# 5110          3.0
# 5189          3.0
# 5268          3.0
# 5347          3.0
# 5584          3.0

# %%
df.drop('Unnamed: 20', axis=1,inplace=True)

# %%
df[~(df['Distrito'].isna())]
# All rows where Distrito is nan can be dropped.
# Out:
#            Distrito Tipo I Ases. Viol. Robo Agr. Grave Esc. Apr. I H. Auto  \
# 0          Adjuntas    117     0     0    6          5   32     69       5
# 1           Aguada     323     4     2   19         13   78    194      13
# 2         Aguadilla    736     5     2   30         24  280    374      21
# 3      Aguas Buenas    261     6     0   28         14  102     89      22
# 4          Aibonito    232     8     0   14         15   62    104      29
# ...             ...    ...   ...   ...  ...        ...  ...    ...     ...
# 10312     Vega Baja    155     5     1    9         14   38     74      14
# 10313       Vieques     47     3     0    0         11   16     15       2
# 10314      Villalba     14     0     0    1          5    3      5       0
# 10315       Yabucoa     32     0     2    0          8    9     12       1
# 10316         Yauco     38     1     0    3         14   11      8       1
#
#           Date
# 0      2014-12
# 1      2014-12
# 2      2014-12
# 3      2014-12
# 4      2014-12
# ...        ...
# 10312  2020-04
# 10313  2020-04
# 10314  2020-04
# 10315  2020-04
# 10316  2020-04
#
# [10296 rows x 10 columns]

# %%
df=df[~(df['Distrito'].isna())]

# %%
df.reset_index(inplace=True, drop=True)

# %%
df
# Out:
#            Distrito Tipo I Ases. Viol. Robo Agr. Grave Esc. Apr. I H. Auto  \
# 0          Adjuntas    117     0     0    6          5   32     69       5
# 1           Aguada     323     4     2   19         13   78    194      13
# 2         Aguadilla    736     5     2   30         24  280    374      21
# 3      Aguas Buenas    261     6     0   28         14  102     89      22
# 4          Aibonito    232     8     0   14         15   62    104      29
# ...             ...    ...   ...   ...  ...        ...  ...    ...     ...
# 10291     Vega Baja    155     5     1    9         14   38     74      14
# 10292       Vieques     47     3     0    0         11   16     15       2
# 10293      Villalba     14     0     0    1          5    3      5       0
# 10294       Yabucoa     32     0     2    0          8    9     12       1
# 10295         Yauco     38     1     0    3         14   11      8       1
#
#           Date
# 0      2014-12
# 1      2014-12
# 2      2014-12
# 3      2014-12
# 4      2014-12
# ...        ...
# 10291  2020-04
# 10292  2020-04
# 10293  2020-04
# 10294  2020-04
# 10295  2020-04
#
# [10296 rows x 10 columns]

# %%
df = df.sort_values(by='Date')

# %%
df.reset_index(inplace=True, drop=True)

# %%
df.isna().sum()
# Out:
# Distrito        0
# Tipo I          0
# Ases.         160
# Viol.         312
# Robo           56
# Agr. Grave      5
# Esc.            7
# Apr. I          0
# H. Auto        86
# Date            0
# dtype: int64

# %%
df[df['Ases.'].isna()]
# Out:
#        Distrito Tipo I Ases. Viol. Robo Agr. Grave Esc. Apr. I H. Auto  \
# 706     Culebra     58   NaN   NaN  NaN          2   17     39     NaN
# 710     Guánica    137   NaN   NaN   10         10   45     67       5
# 715     Hatillo    395   NaN   NaN   30          4  143    122      96
# 721    Adjuntas    258   NaN   NaN   15          9  126    100       8
# 726      Añasco    157   NaN   NaN   15          7   83     41      11
# ...         ...    ...   ...   ...  ...        ...  ...    ...     ...
# 8022    Maricao     26   NaN   NaN  NaN          3    6     17     NaN
# 8025      Lares     98   NaN     1    5         21   27     40       4
# 8028  Naranjito    156   NaN   NaN    7          8   32     90      19
# 8030   Patillas     54   NaN   NaN    2         18    8     26     NaN
# 9098     Utuado    124   NaN     3    4         20   22     73       2
#
#          Date
# 706   2010-10
# 710   2010-10
# 715   2010-10
# 721   2010-10
# 726   2010-10
# ...       ...
# 8022  2018-07
# 8025  2018-07
# 8028  2018-07
# 8030  2018-07
# 9098  2019-09
#
# [160 rows x 10 columns]

# %%
pd.to_datetime(df['Date'])
# Out:
# 0       2010-01-01
# 1       2010-01-01
# 2       2010-01-01
# 3       2010-01-01
# 4       2010-01-01
#            ...
# 10291   2020-12-01
# 10292   2020-12-01
# 10293   2020-12-01
# 10294   2020-12-01
# 10295   2020-12-01
# Name: Date, Length: 10296, dtype: datetime64[ns]

# %%
df.dtypes
# Need to change some of the datatypes to be numeric
# Out:
# Distrito      object
# Tipo I        object
# Ases.         object
# Viol.         object
# Robo          object
# Agr. Grave    object
# Esc.          object
# Apr. I        object
# H. Auto       object
# Date          object
# dtype: object

# %%
df['Tipo I'] = pd.to_numeric(df['Tipo I'])
df['Ases.'] = pd.to_numeric(df['Ases.'])
df['Viol.'] = pd.to_numeric(df['Viol.'])
df['Robo'] = pd.to_numeric(df['Robo'])
df['Agr. Grave'] = pd.to_numeric(df['Agr. Grave'])
df['Esc.'] = pd.to_numeric(df['Esc.'])
df['Apr. I'] = pd.to_numeric(df['Apr. I'])
df['H. Auto'] = pd.to_numeric(df['H. Auto'])

# %%
df.dtypes
# Out:
# Distrito       object
# Tipo I          int64
# Ases.         float64
# Viol.         float64
# Robo          float64
# Agr. Grave    float64
# Esc.          float64
# Apr. I          int64
# H. Auto       float64
# Date           object
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Making sure we strip all distrito names of any whitespaces
df['Distrito'] = df['Distrito'].str.strip()

# %%
print(sorted(df['Distrito'].unique()))
print(len(df['Distrito'].unique()))
# All Distritos are unique
# Out:
# ['Adjuntas', 'Aguada', 'Aguadilla', 'Aguas Buenas', 'Aibonito', 'Arecibo', 'Arroyo', 'Añasco', 'Barceloneta', 'Barranquitas', 'Bayamón', 'Cabo Rojo', 'Caguas', 'Camuy', 'Canóvanas', 'Carolina', 'Cataño', 'Cayey', 'Ceiba', 'Ciales', 'Cidra', 'Coamo', 'Comerío', 'Corozal', 'Culebra', 'Dorado', 'Fajardo', 'Florida', 'Guayama', 'Guayanilla', 'Guaynabo', 'Gurabo', 'Guánica', 'Hatillo', 'Hormigueros', 'Humacao', 'Isabela', 'Jayuya', 'Juana Díaz', 'Juncos', 'Lajas', 'Lares', 'Las Marías', 'Las Piedras', 'Loiza', 'Luquillo', 'Manatí', 'Maricao', 'Maunabo', 'Mayagüez', 'Moca', 'Morovis', 'Naguabo', 'Naranjito', 'Orocovis', 'Patillas', 'Peñuelas', 'Ponce', 'Quebradillas', 'Rincón', 'Rio Grande', 'Sabana Grande', 'Salinas', 'San Germán', 'San Juan', 'San Lorenzo', 'San Sebastián', 'Santa Isabel', 'Toa Alta', 'Toa Baja', 'Trujillo Alto', 'Utuado', 'Vega Alta', 'Vega Baja', 'Vieques', 'Villalba', 'Yabucoa', 'Yauco']
# 78

# %%
def fill_missing(x):
    
    # set nans from first row equal to 0
    # first = x.index[0]
    # x.loc[first] = x.loc[first].fillna(0)
    
    columns = ['Tipo I','Ases.','Viol.','Robo','Agr. Grave','Esc.','Apr. I','H. Auto']
    
    
    x[columns] = x[columns].interpolate() #first linear
    
    x[columns] = x[columns].interpolate(method='ffill') # then forward fill
    x[columns] = x[columns].interpolate(method='bfill') # then backward fill
    
    
    return x
    

df_interpolated = df.groupby(['Distrito', df.Date.dt.year]).apply(fill_missing)

# %%
df_interpolated.isna().sum()
# Out:
# Distrito      0
# Tipo I        0
# Ases.         0
# Viol.         0
# Robo          0
# Agr. Grave    0
# Esc.          0
# Apr. I        0
# H. Auto       0
# Date          0
# dtype: int64

# %%
df_interpolated
# Out:
#        Distrito  Tipo I  Ases.  Viol.  Robo  Agr. Grave   Esc.  Apr. I  \
# 0      Adjuntas      34    0.0    0.0   0.0         1.0   16.0      16
# 1         Ponce     262   11.0    0.0  28.0        27.0   50.0     125
# 2      Peñuelas      12    0.0    1.0   2.0         1.0    2.0       5
# 3      Patillas      17    0.0    0.0   1.0         3.0    8.0       5
# 4      Orocovis      34    0.0    0.0   0.0         2.0   25.0       6
# ...         ...     ...    ...    ...   ...         ...    ...     ...
# 10291  Orocovis      75    1.0    1.0   1.0        11.0   23.0      35
# 10292  Patillas      66    2.0    2.0   2.0        21.0   17.0      21
# 10293     Ponce     754   24.0    3.0  32.0       186.0  125.0     365
# 10294  Mayagüez     241   15.0    4.0   8.0        58.0   47.0      93
# 10295  Peñuelas      57    4.0    0.0   3.0        19.0   14.0      16
#
#        H. Auto       Date
# 0          1.0 2010-01-01
# 1         21.0 2010-01-01
# 2          1.0 2010-01-01
# 3          0.0 2010-01-01
# 4          1.0 2010-01-01
# ...        ...        ...
# 10291      3.0 2020-12-01
# 10292      1.0 2020-12-01
# 10293     18.0 2020-12-01
# 10294     16.0 2020-12-01
# 10295      1.0 2020-12-01
#
# [10296 rows x 10 columns]

# %%
df_interpolated.dtypes
# Out:
# Distrito              object
# Tipo I                 int64
# Ases.                float64
# Viol.                float64
# Robo                 float64
# Agr. Grave           float64
# Esc.                 float64
# Apr. I                 int64
# H. Auto              float64
# Date          datetime64[ns]
# dtype: object

# %%
df_interpolated['Ases.'] = df_interpolated['Ases.'].astype(int)
df_interpolated['Viol.'] = df_interpolated['Viol.'].astype(int)
df_interpolated['Robo'] = df_interpolated['Robo'].astype(int)
df_interpolated['Agr. Grave'] = df_interpolated['Agr. Grave'].astype(int)
df_interpolated['Esc.'] = df_interpolated['Esc.'].astype(int)
df_interpolated['H. Auto'] = df_interpolated['H. Auto'].astype(int)

# %%
df_interpolated
# Out:
#        Distrito  Tipo I  Ases.  Viol.  Robo  Agr. Grave  Esc.  Apr. I  \
# 0      Adjuntas      34      0      0     0           1    16      16
# 1         Ponce     262     11      0    28          27    50     125
# 2      Peñuelas      12      0      1     2           1     2       5
# 3      Patillas      17      0      0     1           3     8       5
# 4      Orocovis      34      0      0     0           2    25       6
# ...         ...     ...    ...    ...   ...         ...   ...     ...
# 10291  Orocovis      75      1      1     1          11    23      35
# 10292  Patillas      66      2      2     2          21    17      21
# 10293     Ponce     754     24      3    32         186   125     365
# 10294  Mayagüez     241     15      4     8          58    47      93
# 10295  Peñuelas      57      4      0     3          19    14      16
#
#        H. Auto       Date
# 0            1 2010-01-01
# 1           21 2010-01-01
# 2            1 2010-01-01
# 3            0 2010-01-01
# 4            1 2010-01-01
# ...        ...        ...
# 10291        3 2020-12-01
# 10292        1 2020-12-01
# 10293       18 2020-12-01
# 10294       16 2020-12-01
# 10295        1 2020-12-01
#
# [10296 rows x 10 columns]

# %%
# df[df['Distrito'] == 'Vega Baja']['Tipo I'].diff()

# %%
# Exporting both interpolated and non interpolated versions of the dataframe
df.to_csv('./data/clean/DelitosTipo1/DelitosTipo1-2010-2020.csv')
df_interpolated.to_csv('./data/clean/DelitosTipo1/DelitosTipo1-2010-2020(interpolado).csv')

# %%
df_interpolated['Date'] = pd.to_datetime(df_interpolated['Date'])

# %%
# Turning data from cumulative into monthly deltas.
def year_to_month(x):
    # Turning into monthly deltas
    cols =['Tipo I','Ases.', 'Viol.', 'Robo', 'Agr. Grave','Esc.', 'Apr. I', 'H. Auto']
    
    x[cols] = x[cols].diff()
    
    return x

df_interpolated_deltas = df_interpolated.groupby(['Distrito', df_interpolated.Date.dt.year]).apply(year_to_month)

# %%
df_interpolated_deltas = df_interpolated_deltas.groupby(['Distrito']).apply(fill_missing)

# %%
df_interpolated_deltas
# Out:
#        Distrito  Tipo I  Ases.  Viol.  Robo  Agr. Grave  Esc.  Apr. I  \
# 0      Adjuntas    34.0    0.0    0.0   4.0         1.0  12.0    16.0
# 1         Ponce   243.0    4.0    0.0  26.0        14.0  52.0   123.0
# 2      Peñuelas    12.0    0.0    0.0   2.0         0.0   6.0     2.0
# 3      Patillas    13.0    0.0    0.0   0.0         4.0   6.0     3.0
# 4      Orocovis    22.0    0.0    0.0   0.0         0.0  10.0    12.0
# ...         ...     ...    ...    ...   ...         ...   ...     ...
# 10291  Orocovis    11.0    0.0    0.0   0.0         2.0   5.0     3.0
# 10292  Patillas     8.0    0.0    0.0   0.0         6.0   1.0     1.0
# 10293     Ponce    71.0    0.0    1.0   6.0        10.0  13.0    40.0
# 10294  Mayagüez    34.0    2.0    0.0   1.0         6.0   6.0    18.0
# 10295  Peñuelas     8.0    0.0    0.0   0.0         4.0   1.0     2.0
#
#        H. Auto       Date
# 0          1.0 2010-01-01
# 1         24.0 2010-01-01
# 2          2.0 2010-01-01
# 3          0.0 2010-01-01
# 4          0.0 2010-01-01
# ...        ...        ...
# 10291      1.0 2020-12-01
# 10292      0.0 2020-12-01
# 10293      1.0 2020-12-01
# 10294      1.0 2020-12-01
# 10295      1.0 2020-12-01
#
# [10296 rows x 10 columns]

# %%
df_interpolated_deltas.isna().sum()
# Out:
# Distrito      0
# Tipo I        0
# Ases.         0
# Viol.         0
# Robo          0
# Agr. Grave    0
# Esc.          0
# Apr. I        0
# H. Auto       0
# Date          0
# dtype: int64

# %%
df_interpolated_deltas.to_csv('./data/clean/DelitosTipo1/DelitosTipo1-2010-2020_deltas_mensuales(interpolado).csv')

# %% [markdown]
# ### Unemployment Rate

# %%
import numpy as np
import pandas as pd

# %%
datasetPersDespl = pd.read_csv("./data/raw/Desempleos/personas_desempleadas_municipal.csv",encoding='iso8859_3')
datasetPersDespl = datasetPersDespl.drop(index = [0])
datasetPersDespl.drop(datasetPersDespl.tail(295).index,inplace = True)
datasetPersDespl
# Out:
#         Date  Puerto Rico SA  Puerto Rico NSA  Adjuntas NSA  Aguada NSA  \
# 1    2020-08           86123            88480         417.0       978.0
# 2    2020-07           87804            75757         348.0       854.0
# 3    2020-06           92311            90194         395.0      1058.0
# 4    2020-05           93122            97038         435.0      1220.0
# 5    2020-02           92713            80739         763.0      1096.0
# ..       ...             ...              ...           ...         ...
# 235  2000-12          127800           114426         567.0      1687.0
# 236  2000-11          124955           114038         516.0      1686.0
# 237  2000-10          123946           127720         560.0      1853.0
# 238  2000-09          124514           123815         550.0      1842.0
# 239  2000-08          126337           143362         660.0      2079.0
#
#      Aguadilla NSA  Aguas Buenas NSA  Aibonito NSA  Añasco NSA  Arecibo NSA  \
# 1           1261.0             594.0         517.0       642.0       1974.0
# 2           1115.0             516.0         451.0       547.0       1767.0
# 3           1307.0             629.0         527.0       671.0       2167.0
# 4           1397.0             673.0         545.0       741.0       2352.0
# 5           1232.0             550.0         583.0       689.0       2054.0
# ..             ...               ...           ...         ...          ...
# 235         2401.0             730.0         802.0      1000.0       3058.0
# 236         2348.0             734.0         773.0       980.0       3157.0
# 237         2616.0             818.0         850.0      1032.0       3493.0
# 238         2562.0             780.0         819.0      1145.0       3423.0
# 239         2987.0             934.0         983.0      1290.0       3814.0
#
#      ...  Coco, Salinas, PR MicroSA NSA  Jayuya, PR MicroSA NSA  \
# 1    ...                          669.0                   304.0
# 2    ...                          560.0                   253.0
# 3    ...                          648.0                   282.0
# 4    ...                          694.0                   267.0
# 5    ...                          876.0                   515.0
# ..   ...                            ...                     ...
# 235  ...                          998.0                   495.0
# 236  ...                         1036.0                   504.0
# 237  ...                         1119.0                   589.0
# 238  ...                         1116.0                   563.0
# 239  ...                         1280.0                   647.0
#
#      Santa Isabel, PR MicroSA NSA  Aguadilla-Isabela, PR MSA NSA  \
# 1                           570.0                         7372.0
# 2                           474.0                         6410.0
# 3                           515.0                         7708.0
# 4                           530.0                         8660.0
# 5                           744.0                         9190.0
# ..                            ...                            ...
# 235                         820.0                        12488.0
# 236                         850.0                        12382.0
# 237                         932.0                        13738.0
# 238                         911.0                        13609.0
# 239                        1060.0                        15789.0
#
#      Arecibo, PR MSA NSA  Guayama, PR MSA NSA  Mayaguez, PR MSA NSA  \
# 1                 4216.0               1523.0                2075.0
# 2                 3728.0               1320.0                1812.0
# 3                 4555.0               1582.0                2225.0
# 4                 5078.0               1677.0                2610.0
# 5                 5368.0               2375.0                2316.0
# ..                   ...                  ...                   ...
# 235               6030.0               2609.0                3816.0
# 236               6165.0               2664.0                3864.0
# 237               6817.0               2975.0                4252.0
# 238               6581.0               2991.0                4314.0
# 239               7525.0               3391.0                4891.0
#
#      Ponce, PR MSA NSA  San Germán, PR MSA NSA  \
# 1               7589.0                  2888.0
# 2               6437.0                  2418.0
# 3               7538.0                  2878.0
# 4               8563.0                  3455.0
# 5               9982.0                  3431.0
# ..                 ...                     ...
# 235            12913.0                  4469.0
# 236            12974.0                  4548.0
# 237            14430.0                  5014.0
# 238            13971.0                  5083.0
# 239            16082.0                  6004.0
#
#      San Juan-Carolina-Caguas, PR MSA NSA
# 1                                 59237.0
# 2                                 50612.0
# 3                                 60277.0
# 4                                 63425.0
# 5                                 43319.0
# ..                                    ...
# 235                               67176.0
# 236                               66478.0
# 237                               75071.0
# 238                               71936.0
# 239                               83476.0
#
# [239 rows x 96 columns]

# %%
datasetTasaDespl = pd.read_csv("./data/raw/Desempleos/tasa_desempleo_municipal.csv",encoding='iso8859_3')
datasetTasaDespl = datasetTasaDespl.drop(index=[0])
datasetTasaDespl.drop(datasetTasaDespl.tail(293).index,inplace = True)

datasetTasaDespl
# Out:
#           Date  Puerto Rico SA  Puerto Rico NSA  Adjuntas NSA  Aguada NSA  \
# 1     8/1/2020             8.3              8.4          10.8         8.7
# 2     7/1/2020             8.5              7.3           9.4         7.6
# 3     6/1/2020             8.9              8.5          10.4         9.2
# 4     5/1/2020             9.0              9.6          11.7        11.1
# 5     4/1/2020             8.8              7.8          18.4         9.7
# ..         ...             ...              ...           ...         ...
# 237  12/1/2000             9.7             10.1          11.4        13.5
# 238  11/1/2000             9.7              9.7          11.1        13.3
# 239  10/1/2000             9.8             11.2          13.2        15.1
# 240   9/1/2000             9.9             10.0          12.3        13.1
# 241   8/1/2000            10.0             10.1          12.4        12.3
#
#      Aguadilla NSA  Aguas Buenas NSA  Aibonito NSA  Añasco NSA  Arecibo NSA  \
# 1              9.1               9.5           8.5         7.6          8.3
# 2              8.1               8.3           7.5         6.6          7.5
# 3              9.3               9.9           8.7         7.9          9.0
# 4             10.5              11.1           9.4         9.1         10.4
# 5              9.0               8.8           9.6         8.2          9.0
# ..             ...               ...           ...         ...          ...
# 237           13.3               9.6          11.3        11.1         10.9
# 238           12.9               9.1          10.9        12.1         10.6
# 239           15.0              10.8          12.9        13.6         11.8
# 240           13.7              10.1          11.8        11.8         10.5
# 241           13.0              10.4          12.3        11.9         10.9
#
#      ...  Coco, Salinas, PR MicroSA NSA  Jayuya, PR MicroSA NSA  \
# 1    ...                           10.1                     7.9
# 2    ...                            8.6                     6.8
# 3    ...                            9.9                     7.4
# 4    ...                           10.9                     7.4
# 5    ...                           13.3                    12.7
# ..   ...                            ...                     ...
# 237  ...                           13.9                    13.0
# 238  ...                           13.7                    12.6
# 239  ...                           15.5                    14.6
# 240  ...                           14.0                    13.1
# 241  ...                           13.8                    12.5
#
#      Santa Isabel, PR MicroSA NSA  Aguadilla-Isabela, PR MSA NSA  \
# 1                             7.7                            9.1
# 2                             6.8                            8.0
# 3                             6.5                            9.4
# 4                             6.9                           11.0
# 5                             8.4                           11.2
# ..                            ...                            ...
# 237                          12.7                           12.9
# 238                          12.8                           12.7
# 239                          14.6                           14.7
# 240                          12.7                           13.3
# 241                          12.4                           13.0
#
#      Arecibo, PR MSA NSA  Guayama, PR MSA NSA  Mayaguez, PR MSA NSA  \
# 1                    8.1                  8.2                   8.1
# 2                    7.2                  7.2                   7.1
# 3                    8.7                  8.4                   8.6
# 4                   10.2                  9.3                  10.4
# 5                   10.5                 12.6                   9.1
# ..                   ...                  ...                   ...
# 237                 10.9                 13.2                  11.4
# 238                 10.4                 13.2                  11.5
# 239                 11.9                 14.8                  13.0
# 240                 10.6                 13.3                  11.5
# 241                 11.0                 13.7                  11.6
#
#      Ponce, PR MSA NSA  San Germán, PR MSA NSA  \
# 1                  8.6                     8.8
# 2                  7.4                     7.5
# 3                  8.5                     8.7
# 4                 10.0                    10.9
# 5                 11.2                    10.4
# ..                 ...                     ...
# 237               12.6                    11.2
# 238               12.3                    11.3
# 239               14.0                    13.2
# 240               12.5                    11.6
# 241               12.2                    11.6
#
#      San Juan-Carolina-Caguas, PR MSA NSA
# 1                                     8.3
# 2                                     7.1
# 3                                     8.3
# 4                                     9.2
# 5                                     6.2
# ..                                    ...
# 237                                   9.0
# 238                                   8.6
# 239                                   9.9
# 240                                   8.8
# 241                                   9.1
#
# [241 rows x 96 columns]

# %%
datasetPersEmpleadas = pd.read_csv("./data/raw/Desempleos/personas_empleadas_municipal.csv",encoding='iso8859_3')
datasetPersEmpleadas = datasetPersEmpleadas.drop(index=[0])
datasetPersEmpleadas.drop(datasetPersEmpleadas.tail(293).index,inplace = True)

datasetPersEmpleadas
# Out:
#           Date  Puerto Rico SA  Puerto Rico NSA  Adjuntas NSA  Aguada NSA  \
# 1     8/1/2020          951707           960458        3461.0     10303.0
# 2     7/1/2020          946949           966381        3361.0     10347.0
# 3     6/1/2020          942830           973196        3393.0     10442.0
# 4     5/1/2020          939024           918881        3281.0      9799.0
# 5     4/1/2020          956078           957316        3375.0     10200.0
# ..         ...             ...              ...           ...         ...
# 237  12/1/2000         1155181          1138016        4331.0     11849.0
# 238  11/1/2000         1159585          1146273        4423.0     11978.0
# 239  10/1/2000         1163225          1131883        4349.0     11720.0
# 240   9/1/2000         1166533          1170012        4511.0     12173.0
# 241   8/1/2000         1169272          1174864        4551.0     12358.0
#
#      Aguadilla NSA  Aguas Buenas NSA  Aibonito NSA  Añasco NSA  Arecibo NSA  \
# 1          12566.0            5641.0        5594.0      7762.0      21873.0
# 2          12581.0            5687.0        5539.0      7792.0      21828.0
# 3          12697.0            5717.0        5511.0      7870.0      21812.0
# 4          11930.0            5403.0        5230.0      7383.0      20286.0
# 5          12474.0            5680.0        5519.0      7693.0      20820.0
# ..             ...               ...           ...         ...          ...
# 237        17109.0            7741.0        6641.0      8262.0      28476.0
# 238        17294.0            7820.0        6710.0      8352.0      28766.0
# 239        16922.0            7727.0        6629.0      8172.0      28421.0
# 240        17577.0            7979.0        6845.0      8488.0      29349.0
# 241        17843.0            7991.0        6856.0      8617.0      29395.0
#
#      ...  Coco, Salinas, PR MicroSA NSA  Jayuya, PR MicroSA NSA  \
# 1    ...                         5958.0                  3544.0
# 2    ...                         5943.0                  3478.0
# 3    ...                         5923.0                  3511.0
# 4    ...                         5681.0                  3364.0
# 5    ...                         5689.0                  3531.0
# ..   ...                            ...                     ...
# 237  ...                         6936.0                  3936.0
# 238  ...                         7051.0                  3895.0
# 239  ...                         6994.0                  3779.0
# 240  ...                         7237.0                  3878.0
# 241  ...                         7329.0                  4066.0
#
#      Santa Isabel, PR MicroSA NSA  Aguadilla-Isabela, PR MSA NSA  \
# 1                          6834.0                        73995.0
# 2                          6504.0                        73834.0
# 3                          7348.0                        74320.0
# 4                          7156.0                        69906.0
# 5                          8088.0                        73009.0
# ..                            ...                            ...
# 237                        6418.0                        92756.0
# 238                        6231.0                        93530.0
# 239                        6190.0                        91591.0
# 240                        6479.0                        95041.0
# 241                        6648.0                        96521.0
#
#      Arecibo, PR MSA NSA  Guayama, PR MSA NSA  Mayaguez, PR MSA NSA  \
# 1                48061.0              16939.0               23397.0
# 2                47972.0              17036.0               23552.0
# 3                47974.0              17167.0               23639.0
# 4                44645.0              16333.0               22371.0
# 5                45735.0              16492.0               23192.0
# ..                   ...                  ...                   ...
# 237              55983.0              19533.0               32994.0
# 238              56554.0              19685.0               33146.0
# 239              55875.0              19559.0               32731.0
# 240              57699.0              20076.0               33983.0
# 241              57790.0              20084.0               34650.0
#
#      Ponce, PR MSA NSA  San Germán, PR MSA NSA  \
# 1              80300.0                 29805.0
# 2              80637.0                 29710.0
# 3              80994.0                 30209.0
# 4              76731.0                 28263.0
# 5              78899.0                 29413.0
# ..                 ...                     ...
# 237           100313.0                 39715.0
# 238            99412.0                 40035.0
# 239            98493.0                 39564.0
# 240           101444.0                 40909.0
# 241           101893.0                 41363.0
#
#      San Juan-Carolina-Caguas, PR MSA NSA
# 1                                652840.0
# 2                                659080.0
# 3                                663268.0
# 4                                626287.0
# 5                                654593.0
# ..                                    ...
# 237                              758365.0
# 238                              765566.0
# 239                              756275.0
# 240                              780914.0
# 241                              782071.0
#
# [241 rows x 96 columns]

# %%
datasetGrupoTrabajador = pd.read_csv("./data/raw/Desempleos/personas_en_grupo_trabajador_municipal.csv",encoding='iso8859_3')
datasetGrupoTrabajador = datasetGrupoTrabajador.drop(index=[0])
datasetGrupoTrabajador.drop(datasetGrupoTrabajador.tail(295).index,inplace = True)

datasetGrupoTrabajador
# Out:
#         Date  Puerto Rico SA  Puerto Rico NSA  Adjuntas NSA  Aguada NSA  \
# 1    2020-08         1037830          1048938        3878.0     11281.0
# 2    2020-07         1034753          1042138        3709.0     11201.0
# 3    2020-06         1035141          1063390        3788.0     11500.0
# 4    2020-05         1032146          1015919        3716.0     11019.0
# 5    2020-02         1048791          1038055        4138.0     11296.0
# ..       ...             ...              ...           ...         ...
# 235  2000-12         1271642          1280556        4918.0     13807.0
# 236  2000-11         1274914          1274382        5003.0     13842.0
# 237  2000-10         1279127          1265736        4891.0     13702.0
# 238  2000-09         1284099          1270088        4973.0     13820.0
# 239  2000-08         1289562          1275245        5009.0     13799.0
#
#      Aguadilla NSA  Aguas Buenas NSA  Aibonito NSA  Añasco NSA  Arecibo NSA  \
# 1          13827.0            6235.0        6111.0      8404.0      23847.0
# 2          13696.0            6203.0        5990.0      8339.0      23595.0
# 3          14004.0            6346.0        6038.0      8541.0      23979.0
# 4          13327.0            6076.0        5775.0      8124.0      22638.0
# 5          13706.0            6230.0        6102.0      8382.0      22874.0
# ..             ...               ...           ...         ...          ...
# 235        19900.0            8672.0        7616.0      9450.0      32275.0
# 236        19901.0            8614.0        7533.0      9456.0      32142.0
# 237        19725.0            8559.0        7491.0      9294.0      31969.0
# 238        19856.0            8600.0        7529.0      9497.0      32189.0
# 239        19909.0            8661.0        7612.0      9462.0      32235.0
#
#      ...  Coco, Salinas, PR MicroSA NSA  Jayuya, PR MicroSA NSA  \
# 1    ...                         6627.0                  3848.0
# 2    ...                         6503.0                  3731.0
# 3    ...                         6571.0                  3793.0
# 4    ...                         6375.0                  3631.0
# 5    ...                         6565.0                  4046.0
# ..   ...                            ...                     ...
# 235  ...                         8069.0                  4428.0
# 236  ...                         8046.0                  4579.0
# 237  ...                         8055.0                  4525.0
# 238  ...                         8167.0                  4458.0
# 239  ...                         8274.0                  4426.0
#
#      Santa Isabel, PR MicroSA NSA  Aguadilla-Isabela, PR MSA NSA  \
# 1                          7404.0                        81367.0
# 2                          6978.0                        80244.0
# 3                          7863.0                        82028.0
# 4                          7686.0                        78566.0
# 5                          8832.0                        82199.0
# ..                            ...                            ...
# 235                        7746.0                       107241.0
# 236                        7596.0                       107534.0
# 237                        7350.0                       106494.0
# 238                        7142.0                       107139.0
# 239                        7250.0                       107380.0
#
#      Arecibo, PR MSA NSA  Guayama, PR MSA NSA  Mayaguez, PR MSA NSA  \
# 1                52277.0              18462.0               25472.0
# 2                51700.0              18356.0               25364.0
# 3                52529.0              18749.0               25864.0
# 4                49723.0              18010.0               24981.0
# 5                51103.0              18867.0               25508.0
# ..                   ...                  ...                   ...
# 235              63468.0              22594.0               37583.0
# 236              63148.0              22509.0               37644.0
# 237              62800.0              22508.0               37246.0
# 238              63135.0              22676.0               37460.0
# 239              63400.0              22950.0               37622.0
#
#      Ponce, PR MSA NSA  San Germán, PR MSA NSA  \
# 1              87889.0                 32693.0
# 2              87074.0                 32128.0
# 3              88532.0                 33087.0
# 4              85294.0                 31718.0
# 5              88881.0                 32844.0
# ..                 ...                     ...
# 235           115311.0                 45111.0
# 236           115471.0                 45312.0
# 237           114743.0                 44729.0
# 238           113383.0                 45118.0
# 239           114575.0                 45568.0
#
#      San Juan-Carolina-Caguas, PR MSA NSA
# 1                                712077.0
# 2                                709692.0
# 3                                723545.0
# 4                                689712.0
# 5                                697912.0
# ..                                    ...
# 235                              845088.0
# 236                              838129.0
# 237                              833436.0
# 238                              837502.0
# 239                              839751.0
#
# [239 rows x 96 columns]

# %% [markdown]
# First melting the data of each dataframe to turn the district and city columns into rows.

# %%
df_tasa_melt = pd.melt(datasetTasaDespl,
        id_vars=['Date'],
        var_name='Municipio o Area',
        value_name='Tasa de Desempleo'
       )

# %%
df_desempleados_melt = pd.melt(datasetPersDespl,
        id_vars=['Date'],
        var_name='Municipio o Area',
        value_name='Num. Personas Desempleadas'
       )

# %%
df_empleados_melt = pd.melt(datasetPersEmpleadas,
        id_vars=['Date'],
        var_name='Municipio o Area',
        value_name='Num. Personas Empleadas'
       )

# %%
df_grupo_trabajador_melt = pd.melt(datasetGrupoTrabajador,
        id_vars=['Date'],
        var_name='Municipio o Area',
        value_name='Num. Personas Grupo Trabajador'
       )

# %% [markdown]
# Performing datetime conversion on all of these

# %%
df_tasa_melt['Date'] = pd.to_datetime(df_tasa_melt.Date)
df_desempleados_melt['Date'] = pd.to_datetime(df_desempleados_melt.Date)
df_empleados_melt['Date'] = pd.to_datetime(df_empleados_melt.Date)
df_grupo_trabajador_melt['Date'] = pd.to_datetime(df_grupo_trabajador_melt.Date)

# %%
df_tasa_melt
# Out:
#             Date                      Municipio o Area  Tasa de Desempleo
# 0     2020-08-01                        Puerto Rico SA                8.3
# 1     2020-07-01                        Puerto Rico SA                8.5
# 2     2020-06-01                        Puerto Rico SA                8.9
# 3     2020-05-01                        Puerto Rico SA                9.0
# 4     2020-04-01                        Puerto Rico SA                8.8
# ...          ...                                   ...                ...
# 22890 2000-12-01  San Juan-Carolina-Caguas, PR MSA NSA                9.0
# 22891 2000-11-01  San Juan-Carolina-Caguas, PR MSA NSA                8.6
# 22892 2000-10-01  San Juan-Carolina-Caguas, PR MSA NSA                9.9
# 22893 2000-09-01  San Juan-Carolina-Caguas, PR MSA NSA                8.8
# 22894 2000-08-01  San Juan-Carolina-Caguas, PR MSA NSA                9.1
#
# [22895 rows x 3 columns]

# %%
df_desempleados_melt
# Out:
#             Date                      Municipio o Area  \
# 0     2020-08-01                        Puerto Rico SA
# 1     2020-07-01                        Puerto Rico SA
# 2     2020-06-01                        Puerto Rico SA
# 3     2020-05-01                        Puerto Rico SA
# 4     2020-02-01                        Puerto Rico SA
# ...          ...                                   ...
# 22700 2000-12-01  San Juan-Carolina-Caguas, PR MSA NSA
# 22701 2000-11-01  San Juan-Carolina-Caguas, PR MSA NSA
# 22702 2000-10-01  San Juan-Carolina-Caguas, PR MSA NSA
# 22703 2000-09-01  San Juan-Carolina-Caguas, PR MSA NSA
# 22704 2000-08-01  San Juan-Carolina-Caguas, PR MSA NSA
#
#        Num. Personas Desempleadas
# 0                         86123.0
# 1                         87804.0
# 2                         92311.0
# 3                         93122.0
# 4                         92713.0
# ...                           ...
# 22700                     67176.0
# 22701                     66478.0
# 22702                     75071.0
# 22703                     71936.0
# 22704                     83476.0
#
# [22705 rows x 3 columns]

# %%
df_empleados_melt
# Out:
#             Date                      Municipio o Area  \
# 0     2020-08-01                        Puerto Rico SA
# 1     2020-07-01                        Puerto Rico SA
# 2     2020-06-01                        Puerto Rico SA
# 3     2020-05-01                        Puerto Rico SA
# 4     2020-04-01                        Puerto Rico SA
# ...          ...                                   ...
# 22890 2000-12-01  San Juan-Carolina-Caguas, PR MSA NSA
# 22891 2000-11-01  San Juan-Carolina-Caguas, PR MSA NSA
# 22892 2000-10-01  San Juan-Carolina-Caguas, PR MSA NSA
# 22893 2000-09-01  San Juan-Carolina-Caguas, PR MSA NSA
# 22894 2000-08-01  San Juan-Carolina-Caguas, PR MSA NSA
#
#        Num. Personas Empleadas
# 0                     951707.0
# 1                     946949.0
# 2                     942830.0
# 3                     939024.0
# 4                     956078.0
# ...                        ...
# 22890                 758365.0
# 22891                 765566.0
# 22892                 756275.0
# 22893                 780914.0
# 22894                 782071.0
#
# [22895 rows x 3 columns]

# %%
df_grupo_trabajador_melt
# Out:
#             Date                      Municipio o Area  \
# 0     2020-08-01                        Puerto Rico SA
# 1     2020-07-01                        Puerto Rico SA
# 2     2020-06-01                        Puerto Rico SA
# 3     2020-05-01                        Puerto Rico SA
# 4     2020-02-01                        Puerto Rico SA
# ...          ...                                   ...
# 22700 2000-12-01  San Juan-Carolina-Caguas, PR MSA NSA
# 22701 2000-11-01  San Juan-Carolina-Caguas, PR MSA NSA
# 22702 2000-10-01  San Juan-Carolina-Caguas, PR MSA NSA
# 22703 2000-09-01  San Juan-Carolina-Caguas, PR MSA NSA
# 22704 2000-08-01  San Juan-Carolina-Caguas, PR MSA NSA
#
#        Num. Personas Grupo Trabajador
# 0                           1037830.0
# 1                           1034753.0
# 2                           1035141.0
# 3                           1032146.0
# 4                           1048791.0
# ...                               ...
# 22700                        845088.0
# 22701                        838129.0
# 22702                        833436.0
# 22703                        837502.0
# 22704                        839751.0
#
# [22705 rows x 3 columns]

# %% [markdown]
# Performing a merge of all these attributes into a single dataframe.

# %%
df_final = pd.merge(df_tasa_melt, df_desempleados_melt)
df_final = pd.merge(df_final, df_empleados_melt)
df_final = pd.merge(df_final, df_grupo_trabajador_melt)

# %%
df_final.isna().sum()
# Out:
# Date                              0
# Municipio o Area                  0
# Tasa de Desempleo                 0
# Num. Personas Desempleadas        0
# Num. Personas Empleadas           0
# Num. Personas Grupo Trabajador    0
# dtype: int64

# %%
df_final.dtypes
# Out:
# Date                              datetime64[ns]
# Municipio o Area                          object
# Tasa de Desempleo                        float64
# Num. Personas Desempleadas               float64
# Num. Personas Empleadas                  float64
# Num. Personas Grupo Trabajador           float64
# dtype: object

# %% [markdown]
# ### Stripping out any whitespaces from names and also removing the NSA abreviation from it (NSA stands for None-Seasonally Adjustes)
#
# For the sake of simplicity in our analysis we will suppose that None-Seasonally Adjusted values are the the samae as normal values. It is good to keep this in mind since about 13 of the cities aren't NSA and could provide differing results.

# %%
df_final['Municipio o Area'] = df_final[
    'Municipio o Area'].str.replace(" NSA", "")

# %%
df_final['Municipio o Area'] = df_final[
    'Municipio o Area'].str.strip()

# %%
# Changing Mayaguez to Mayagüez
df_final.loc[df_final['Municipio o Area'] == 'Mayaguez',
             'Municipio o Area'] = 'Mayagüez'

# %%
# Changing Juana Diaz to Juana Díaz
df_final.loc[df_final['Municipio o Area'] == 'Juana Diaz',
             'Municipio o Area'] = 'Juana Díaz'

# %%
df_final['Municipio o Area'].unique()
# Out:
# array(['Puerto Rico SA', 'Puerto Rico', 'Adjuntas', 'Aguada', 'Aguadilla',
#        'Aguas Buenas', 'Aibonito', 'Añasco', 'Arecibo', 'Arroyo',
#        'Barceloneta', 'Barranquitas', 'Bayamón', 'Cabo Rojo', 'Caguas',
#        'Camuy', 'Canóvanas', 'Carolina', 'Cataño', 'Cayey', 'Ceiba',
#        'Ciales', 'Cidra', 'Coamo', 'Comerío', 'Corozal', 'Culebra',
#        'Dorado', 'Fajardo', 'Florida', 'Guánica', 'Guayama', 'Guayanilla',
#        'Guaynabo', 'Gurabo', 'Hatillo', 'Hormigueros', 'Humacao',
#        'Isabela', 'Jayuya', 'Juana Díaz', 'Juncos', 'Lajas', 'Lares',
#        'Las Marías', 'Las Piedras', 'Loiza', 'Luquillo', 'Manatí',
#        'Maricao', 'Maunabo', 'Mayagüez', 'Moca', 'Morovis', 'Naguabo',
#        'Naranjito', 'Orocovis', 'Patillas', 'Peñuelas', 'Ponce',
#        'Quebradillas', 'Rincón', 'Rio Grande', 'Sabana Grande', 'Salinas',
#        'San Germán', 'San Juan', 'San Lorenzo', 'San Sebastián',
#        'Santa Isabel', 'Toa Alta', 'Toa Baja', 'Trujillo Alto', 'Utuado',
#        'Vega Alta', 'Vega Baja', 'Vieques', 'Villalba', 'Yabucoa',
#        'Yauco', 'Mayaguez-San Germán, PR CSA',
#        'Ponce-Coamo-Santa Isabel, PR CSA', 'San Juan-Carolina, PR CSA',
#        'Adjuntas, PR MicroSA', 'Coamo, PR MicroSA',
#        'Coco, Salinas, PR MicroSA', 'Jayuya, PR MicroSA',
#        'Santa Isabel, PR MicroSA', 'Aguadilla-Isabela, PR MSA',
#        'Arecibo, PR MSA', 'Guayama, PR MSA', 'Mayaguez, PR MSA',
#        'Ponce, PR MSA', 'San Germán, PR MSA',
#        'San Juan-Carolina-Caguas, PR MSA'], dtype=object)

# %%
df_final['Municipio o Area'].unique().size
# Out:
# 95

# %%
df_final.to_csv(
    "./data/clean/Tasa de Desempleos/tasa_de_desempleos_y_mas_limpio.csv",
    index=False
)
